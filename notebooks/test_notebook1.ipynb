# %%
from eeg_denoising.config import PATH_TO_TUAR_JSON, PATH_TO_TUAR_EDF_FILES
from eeg_denoising.config import TAUR_MONTAGE

import matplotlib.pyplot as plt
from mne.io import read_raw_edf
from mne.viz import plot_montage

# %%
raw_edf = read_raw_edf(PATH_TO_TUAR_EDF_FILES /'aaaaadmi_s013_t013.edf', preload=True)

print(raw_edf.get_data().nbytes / 1e6) # Size in megabytes.
